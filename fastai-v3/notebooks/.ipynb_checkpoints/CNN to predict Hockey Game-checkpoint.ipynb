# %% [markdown]
# # Roller Hockey vs. Ice Hockey a CNN Classifier
#
# ## *note: to run this ensure I move the images back into this directory*
#
# As a lifelong roller hockey player...don't I look awesome as an All-Star representing my Highschool team! I thought it would be fun to build a classifier that could predict whether it was being given an ice hockey photo or a roller hockey photo, given how similar most images appear (helmet, gloves, stick, etc.).
#
# ![Me](https://i.imgur.com/pXOY3i0.jpg)
#
#
# Just for fun I added in Lacrosse, but my guess is the grass gives that one away fairly easily. So this will be a 3 class classifier, with roughly 185 photos from each sport included. Let's see how good we can do.

# %%
from fastai.vision import *

# %%
path = Path('sports')
dest = path
dest.mkdir(parents=True, exist_ok=True)

# %%
path.ls()
# Out:
# [PosixPath('sports/lacrosse'),
#  PosixPath('sports/roller_hockey'),
#  PosixPath('sports/ice_hockey'),
#  PosixPath('sports/models')]

# %%
classes = ['roller_hockey','ice_hockey', 'lacrosse']

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.25,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['ice_hockey', 'lacrosse', 'roller_hockey']

# %%
data.show_batch(rows=4, figsize=(15,11))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['ice_hockey', 'lacrosse', 'roller_hockey'], 3, 404, 134)

# %% [markdown]
# # Train the Model

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(12)
# Out:
# Total time: 02:21 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>1.284728</th>
#     <th>0.893375</th>
#     <th>0.395522</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.963846</th>
#     <th>0.429158</th>
#     <th>0.179104</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.747919</th>
#     <th>0.257709</th>
#     <th>0.104478</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.614292</th>
#     <th>0.223971</th>
#     <th>0.097015</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.509163</th>
#     <th>0.211726</th>
#     <th>0.089552</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.425597</th>
#     <th>0.202894</th>
#     <th>0.082090</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.373236</th>
#     <th>0.182718</th>
#     <th>0.074627</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.326753</th>
# ...

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(8, max_lr=slice(1e-04,1e-03))
# Out:
# Total time: 01:38 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.116107</th>
#     <th>0.164866</th>
#     <th>0.082090</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.101593</th>
#     <th>0.368765</th>
#     <th>0.126866</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.104174</th>
#     <th>0.408430</th>
#     <th>0.104478</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.100734</th>
#     <th>0.262495</th>
#     <th>0.067164</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.083499</th>
#     <th>0.287576</th>
#     <th>0.082090</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.078154</th>
#     <th>0.148751</th>
#     <th>0.044776</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.069636</th>
#     <th>0.108145</th>
#     <th>0.037313</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.063104</th>
# ...

# %%
learn.save('stage-2')

# %% [markdown]
# # Interpretation

# %%
learn.load('stage-2');

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_top_losses(9, figsize=(15,11))
